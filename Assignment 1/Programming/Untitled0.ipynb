# %%
import numpy as np
X= np.array([4,2,3,2,3,2.5,2])
Y=np.array([5,3,2,4,3,2,2])
p2 = np.polyfit(X,Y,2)
import matplotlib.pyplot as plt
# %matplotlib inline
p6 =np.polyval((X,Y),2)
plt.scatter(X,Y)
plt.plot(X,np.polyval(p6,X))
